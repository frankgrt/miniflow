# %%
"""
Implement the backward method of the Sigmoid node.
"""
import numpy as np


class Node(object):
    """
    Base class for nodes in the network.

    Arguments:

        `inbound_nodes`: A list of nodes with edges into this node.
    """
    def __init__(self, inbound_nodes=[]):
        """
        Node's constructor (runs when the object is instantiated). Sets
        properties that all nodes need.
        """
        # A list of nodes with edges into this node.
        self.inbound_nodes = inbound_nodes
        # The eventual value of this node. Set by running
        # the forward() method.
        self.value = None
        # A list of nodes that this node outputs to.
        self.outbound_nodes = []
        # New property! Keys are the inputs to this node and
        # their values are the partials of this node with
        # respect to that input.
        self.gradients = {}
        # Sets this node as an outbound node for all of
        # this node's inputs.
        for node in inbound_nodes:
            node.outbound_nodes.append(self)

    def forward(self):
        """
        need to define its own `forward` method.
        Every node that uses this class as a base class will
        """
        raise NotImplementedError

    def backward(self):
        """
        Every node that uses this class as a base class will
        need to define its own `backward` method.
        """
        raise NotImplementedError


class Input(Node):
    """
    A generic input into the network.
    """
    def __init__(self):
        # The base class constructor has to run to set all
        # the properties here.
        #
        # The most important property on an Input is value.
        # self.value is set during `topological_sort` later.
        Node.__init__(self)

    def forward(self):
        # Do nothing because nothing is calculated.
        pass

    def backward(self):
        # An Input node has no inputs so the gradient (derivative)
        # is zero.
        # The key, `self`, is reference to this object.
        self.gradients = {self: 0}
        # Weights and bias may be inputs, so you need to sum
        # the gradient from output gradients.
        for n in self.outbound_nodes:
            grad_cost = n.gradients[self]
            self.gradients[self] += grad_cost * 1


class Linear(Node):
    """
    Represents a node that performs a linear transform.

    """
    def __init__(self, X, W, b):
        # The base class (Node) constructor. Weights and bias
        # are treated like inbound nodes.
        Node.__init__(self, [X, W, b])

    def forward(self):
        """
        Performs the math behind a linear transform.
        """
        X = self.inbound_nodes[0].value
        W = self.inbound_nodes[1].value
        b = self.inbound_nodes[2].value
        self.value = np.dot(X, W) + b

    def backward(self):
        """
        Calculates the gradient based on the output values.
        """
        # Initialize a partial for each of the inbound_nodes.
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_nodes}
        # Cycle through the outputs. The gradient will change depending
        # on each output, so the gradients are summed over all outputs.
        for n in self.outbound_nodes:
            # Get the partial of the cost with respect to this node.
            grad_cost = n.gradients[self]
            # Set the partial of the loss with respect to this node's inputs.
            self.gradients[self.inbound_nodes[0]] += np.dot(grad_cost, self.inbound_nodes[1].value.T)
            # Set the partial of the loss with respect to this node's weights.
            self.gradients[self.inbound_nodes[1]] += (np.dot(grad_cost.T,self.inbound_nodes[0].value)).T
            # Set the partial of the loss with respect to this node's bias.
            self.gradients[self.inbound_nodes[2]] += np.sum(grad_cost, axis=0, keepdims=False)
            

class Sigmoid(Node):
    """
    Represents a node that performs the sigmoid activation function.
    """
    def __init__(self, node):
        # The base class constructor.
        Node.__init__(self, [node])

    def _sigmoid(self, x):
        """
        This method is separate from `forward` because it
        will be used with `backward` as well.

        `x`: A numpy array-like object.
        """
        return 1. / (1. + np.exp(-x))

    def forward(self):
        """
        Perform the sigmoid function and set the value.
        """
        input_value = self.inbound_nodes[0].value
        self.value = self._sigmoid(input_value)

    def backward(self):
        """
        Calculates the gradient using the derivative of
        the sigmoid function.
        """
        # Initialize the gradients to 0.
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_nodes}

        # Cycle through the outputs. The gradient will change depending
        # on each output, so the gradients are summed over all outputs.
        for n in self.outbound_nodes:
            # Get the partial of the cost with respect to this node.
            grad_cost = n.gradients[self]
            """
            TODO: Your code goes here!

            Set the gradients property to the gradients with respect to each input.

            NOTE: See the Linear node and MSE node for examples.
            """

            self.gradients[self.inbound_nodes[0]] = grad_cost *  self.value * (1 - self.value )


class MSE(Node):
    def __init__(self, y, a):
        """
        The mean squared error cost function.
        Should be used as the last node for a network.
        """
        # Call the base class' constructor.
        Node.__init__(self, [y, a])

    def forward(self):
        """
        Calculates the mean squared error.
        """
        # NOTE: We reshape these to avoid possible matrix/vector broadcast
        # errors.
        #
        # For example, if we subtract an array of shape (3,) from an array of shape
        # (3,1) we get an array of shape(3,3) as the result when we want
        # an array of shape (3,1) instead.
        #
        # Making both arrays (3,1) insures the result is (3,1) and does
        # an elementwise subtraction as expected.
        y = self.inbound_nodes[0].value.reshape(-1, 1)
        a = self.inbound_nodes[1].value.reshape(-1, 1)

        self.m = self.inbound_nodes[0].value.shape[0]
        # Save the computed output for backward.
        self.diff = y - a
        self.value = np.mean(self.diff**2)

    def backward(self):
        """
        Calculates the gradient of the cost.

        This is the final node of the network so outbound nodes
        are not a concern.
        """
        self.gradients[self.inbound_nodes[0]] = (2 / self.m) * self.diff
        self.gradients[self.inbound_nodes[1]] = (-2 / self.m) * self.diff


def topological_sort(feed_dict):
    """
    Sort the nodes in topological order using Kahn's Algorithm.

    `feed_dict`: A dictionary where the key is a `Input` Node and the value is the respective value feed to that Node.

    Returns a list of sorted nodes.
    """

    input_nodes = [n for n in feed_dict.keys()]

    G = {}
    nodes = [n for n in input_nodes]
    while len(nodes) > 0:
        n = nodes.pop(0)
        if n not in G:
            G[n] = {'in': set(), 'out': set()}
        for m in n.outbound_nodes:
            if m not in G:
                G[m] = {'in': set(), 'out': set()}
            G[n]['out'].add(m)
            G[m]['in'].add(n)
            nodes.append(m)

    L = []
    S = set(input_nodes)
    while len(S) > 0:
        n = S.pop()

        if isinstance(n, Input):
            n.value = feed_dict[n]

        L.append(n)
        for m in n.outbound_nodes:
            G[n]['out'].remove(m)
            G[m]['in'].remove(n)
            # if no other incoming edges add to S
            if len(G[m]['in']) == 0:
                S.add(m)
    return L


def forward_and_backward(graph):
    """
    Performs a forward pass and a backward pass through a list of sorted Nodes.

    Arguments:

        `graph`: The result of calling `topological_sort`.
    """
    # Forward pass
    for n in graph:
        n.forward()

    # Backward pass
    # see: https://docs.python.org/2.3/whatsnew/section-slices.html
    for n in graph[::-1]:
        n.backward()

# %%
"""
Test your network here!

No need to change this code, but feel free to tweak it
to test your network!

Make your changes to backward method of the Sigmoid class in miniflow.py
"""

import numpy as np
#from miniflow import *

X, W, b = Input(), Input(), Input()
y = Input()
f = Linear(X, W, b)
a = Sigmoid(f)
cost = MSE(y, a)

X_ = np.array([[-1., -2.], [-1, -2]])
W_ = np.array([[2.], [3.]])
b_ = np.array([-3.])
y_ = np.array([1, 2])

feed_dict = {
    X: X_,
    y: y_,
    W: W_,
    b: b_,
}

graph = topological_sort(feed_dict)
forward_and_backward(graph)
# return the gradients for each Input
gradients = [np.round(t.gradients[t],10) for t in [X, y, W, b]]

"""
Expected output

[array([[ -3.34017280e-05,  -5.01025919e-05],
       [ -6.68040138e-05,  -1.00206021e-04]]), array([[ 0.9999833],
       [ 1.9999833]]), array([[  5.01028709e-05],
       [  1.00205742e-04]]), array([ -5.01028709e-05])]
"""

#print(gradients)
#print (cost.value)
print (cost.gradients[y])
print (cost.gradients[a])
print (cost.m)
# Out:
# [[ 0.9999833]
#  [ 1.9999833]]
# [[-0.9999833]
#  [-1.9999833]]
# 2

# %%
a.gradients
# Out:
# {<__main__.Linear at 0x1dcf630b978>: array([[ -1.67008640e-05],
#         [ -3.34020069e-05]])}

# %%
a.gradients[f]
# Out:
# array([[ -1.67008640e-05],
#        [ -3.34020069e-05]])

# %%
print(gradients)
# Out:
# [array([[ -3.34017000e-05,  -5.01026000e-05],
#        [ -6.68040000e-05,  -1.00206000e-04]]), array([[ 0.9999833],
#        [ 1.9999833]]), array([[  5.01029000e-05],
#        [  1.00205700e-04]]), array([ -5.01029000e-05])]

# %%
import numpy as np


class Node(object):
    """
    Base class for nodes in the network.

    Arguments:

        `inbound_nodes`: A list of nodes with edges into this node.
    """
    def __init__(self, inbound_nodes=[]):
        """
        Node's constructor (runs when the object is instantiated). Sets
        properties that all nodes need.
        """
        # A list of nodes with edges into this node.
        self.inbound_nodes = inbound_nodes
        # The eventual value of this node. Set by running
        # the forward() method.
        self.value = None
        # A list of nodes that this node outputs to.
        self.outbound_nodes = []
        # New property! Keys are the inputs to this node and
        # their values are the partials of this node with
        # respect to that input.
        self.gradients = {}
        # Sets this node as an outbound node for all of
        # this node's inputs.
        for node in inbound_nodes:
            node.outbound_nodes.append(self)

    def forward(self):
        """
        Every node that uses this class as a base class will
        need to define its own `forward` method.
        """
        raise NotImplementedError

    def backward(self):
        """
        Every node that uses this class as a base class will
        need to define its own `backward` method.
        """
        raise NotImplementedError


class Input(Node):
    """
    A generic input into the network.
    """
    def __init__(self):
        # The base class constructor has to run to set all
        # the properties here.
        #
        # The most important property on an Input is value.
        # self.value is set during `topological_sort` later.
        Node.__init__(self)

    def forward(self):
        # Do nothing because nothing is calculated.
        pass

    def backward(self):
        # An Input node has no inputs so the gradient (derivative)
        # is zero.
        # The key, `self`, is reference to this object.
        self.gradients = {self: 0}
        # Weights and bias may be inputs, so you need to sum
        # the gradient from output gradients.
        for n in self.outbound_nodes:
            self.gradients[self] += n.gradients[self]

class Linear(Node):
    """
    Represents a node that performs a linear transform.
    """
    def __init__(self, X, W, b):
        # The base class (Node) constructor. Weights and bias
        # are treated like inbound nodes.
        Node.__init__(self, [X, W, b])

    def forward(self):
        """
        Performs the math behind a linear transform.
        """
        X = self.inbound_nodes[0].value
        W = self.inbound_nodes[1].value
        b = self.inbound_nodes[2].value
        self.value = np.dot(X, W) + b

    def backward(self):
        """
        Calculates the gradient based on the output values.
        """
        # Initialize a partial for each of the inbound_nodes.
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_nodes}
        # Cycle through the outputs. The gradient will change depending
        # on each output, so the gradients are summed over all outputs.
        for n in self.outbound_nodes:
            # Get the partial of the cost with respect to this node.
            grad_cost = n.gradients[self]
            # Set the partial of the loss with respect to this node's inputs.
            self.gradients[self.inbound_nodes[0]] += np.dot(grad_cost, self.inbound_nodes[1].value.T)
            # Set the partial of the loss with respect to this node's weights.
            self.gradients[self.inbound_nodes[1]] += np.dot(self.inbound_nodes[0].value.T, grad_cost)
            # Set the partial of the loss with respect to this node's bias.
            self.gradients[self.inbound_nodes[2]] += np.sum(grad_cost, axis=0, keepdims=False)


class Sigmoid(Node):
    """
    Represents a node that performs the sigmoid activation function.
    """
    def __init__(self, node):
        # The base class constructor.
        Node.__init__(self, [node])

    def _sigmoid(self, x):
        """
        This method is separate from `forward` because it
        will be used with `backward` as well.

        `x`: A numpy array-like object.
        """
        return 1. / (1. + np.exp(-x))

    def forward(self):
        """
        Perform the sigmoid function and set the value.
        """
        input_value = self.inbound_nodes[0].value
        self.value = self._sigmoid(input_value)

    def backward(self):
        """
        Calculates the gradient using the derivative of
        the sigmoid function.
        """
        # Initialize the gradients to 0.
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_nodes}
        # Sum the partial with respect to the input over all the outputs.
        for n in self.outbound_nodes:
            grad_cost = n.gradients[self]
            sigmoid = self.value
            self.gradients[self.inbound_nodes[0]] += sigmoid * (1 - sigmoid) * grad_cost


class MSE(Node):
    def __init__(self, y, a):
        """
        The mean squared error cost function.
        Should be used as the last node for a network.
        """
        # Call the base class' constructor.
        Node.__init__(self, [y, a])

    def forward(self):
        """
        Calculates the mean squared error.
        """
        # NOTE: We reshape these to avoid possible matrix/vector broadcast
        # errors.
        #
        # For example, if we subtract an array of shape (3,) from an array of shape
        # (3,1) we get an array of shape(3,3) as the result when we want
        # an array of shape (3,1) instead.
        #
        # Making both arrays (3,1) insures the result is (3,1) and does
        # an elementwise subtraction as expected.
        y = self.inbound_nodes[0].value.reshape(-1, 1)
        a = self.inbound_nodes[1].value.reshape(-1, 1)

        self.m = self.inbound_nodes[0].value.shape[0]
        # Save the computed output for backward.
        self.diff = y - a
        self.value = np.mean(self.diff**2)

    def backward(self):
        """
        Calculates the gradient of the cost.
        """
        self.gradients[self.inbound_nodes[0]] = (2 / self.m) * self.diff
        self.gradients[self.inbound_nodes[1]] = (-2 / self.m) * self.diff


def topological_sort(feed_dict):
    """
    Sort the nodes in topological order using Kahn's Algorithm.

    `feed_dict`: A dictionary where the key is a `Input` Node and the value is the respective value feed to that Node.

    Returns a list of sorted nodes.
    """

    input_nodes = [n for n in feed_dict.keys()]

    G = {}
    nodes = [n for n in input_nodes]
    while len(nodes) > 0:
        n = nodes.pop(0)
        if n not in G:
            G[n] = {'in': set(), 'out': set()}
        for m in n.outbound_nodes:
            if m not in G:
                G[m] = {'in': set(), 'out': set()}
            G[n]['out'].add(m)
            G[m]['in'].add(n)
            nodes.append(m)

    L = []
    S = set(input_nodes)
    while len(S) > 0:
        n = S.pop()

        if isinstance(n, Input):
            n.value = feed_dict[n]

        L.append(n)
        for m in n.outbound_nodes:
            G[n]['out'].remove(m)
            G[m]['in'].remove(n)
            # if no other incoming edges add to S
            if len(G[m]['in']) == 0:
                S.add(m)
    return L


def forward_and_backward(graph):
    """
    Performs a forward pass and a backward pass through a list of sorted Nodes.

    Arguments:

        `graph`: The result of calling `topological_sort`.
    """
    # Forward pass
    for n in graph:
        n.forward()

    # Backward pass
    # see: https://docs.python.org/2.3/whatsnew/section-slices.html
    for n in graph[::-1]:
        n.backward()


def sgd_update(trainables, learning_rate=1e-2):
    """
    Updates the value of each trainable with SGD.

    Arguments:

        `trainables`: A list of `Input` Nodes representing weights/biases.
        `learning_rate`: The learning rate.
    """
    # TODO: update all the `trainables` with SGD
    # You can access and assign the value of a trainable with `value` attribute.
    # Example:
    for t in trainables:
        t.value -= learning_rate *t.outbound_nodes[0].gradients[t]
    return

# %%
"""
Check out the new network architecture and dataset!

Notice that the weights and biases are
generated randomly.

No need to change anything, but feel free to tweak
to test your network, play around with the epochs, batch size, etc!
"""

import numpy as np
from sklearn.datasets import load_boston
from sklearn.utils import shuffle, resample
from miniflow import *

# Load data
data = load_boston()
X_ = data['data']
y_ = data['target']

# Normalize data
X_ = (X_ - np.mean(X_, axis=0)) / np.std(X_, axis=0)

n_features = X_.shape[1]
n_hidden = 10
W1_ = np.random.randn(n_features, n_hidden)
b1_ = np.zeros(n_hidden)
W2_ = np.random.randn(n_hidden, 1)
b2_ = np.zeros(1)

# Neural network
X, y = Input(), Input()
W1, b1 = Input(), Input()
W2, b2 = Input(), Input()

l1 = Linear(X, W1, b1)
s1 = Sigmoid(l1)
l2 = Linear(s1, W2, b2)
cost = MSE(y, l2)

feed_dict = {
    X: X_,
    y: y_,
    W1: W1_,
    b1: b1_,
    W2: W2_,
    b2: b2_
}

epochs = 1000
# Total number of examples
m = X_.shape[0]
batch_size = 11
steps_per_epoch = m // batch_size

graph = topological_sort(feed_dict)
trainables = [W1, b1, W2, b2]

print("Total number of examples = {}".format(m))

# Step 4
for i in range(epochs):
    loss = 0
    for j in range(steps_per_epoch):
        # Step 1
        # Randomly sample a batch of examples
        X_batch, y_batch = resample(X_, y_, n_samples=batch_size)

        # Reset value of X and y Inputs
        X.value = X_batch
        y.value = y_batch

        # Step 2
        forward_and_backward(graph)

        # Step 3
        sgd_update(trainables)

        loss += graph[-1].value

    print("Epoch: {}, Loss: {:.3f}".format(i+1, loss/steps_per_epoch))
# Out:
# Total number of examples = 506
# Epoch: 1, Loss: 128.658
# Epoch: 2, Loss: 30.377
# Epoch: 3, Loss: 27.757
# Epoch: 4, Loss: 28.763
# Epoch: 5, Loss: 29.291
# Epoch: 6, Loss: 22.249
# Epoch: 7, Loss: 19.904
# Epoch: 8, Loss: 20.218
# Epoch: 9, Loss: 17.866
# Epoch: 10, Loss: 13.970
# Epoch: 11, Loss: 12.937
# Epoch: 12, Loss: 15.362
# Epoch: 13, Loss: 12.488
# Epoch: 14, Loss: 11.429
# Epoch: 15, Loss: 11.059
# Epoch: 16, Loss: 12.563
# Epoch: 17, Loss: 11.030
# Epoch: 18, Loss: 9.610
# Epoch: 19, Loss: 12.008
# Epoch: 20, Loss: 12.121
# Epoch: 21, Loss: 9.663
# Epoch: 22, Loss: 11.421
# Epoch: 23, Loss: 9.329
# Epoch: 24, Loss: 10.513
# Epoch: 25, Loss: 10.940
# Epoch: 26, Loss: 11.926
# Epoch: 27, Loss: 8.386
# Epoch: 28, Loss: 8.144
# Epoch: 29, Loss: 8.821
# Epoch: 30, Loss: 10.636
# Epoch: 31, Loss: 9.176
# Epoch: 32, Loss: 8.447
# Epoch: 33, Loss: 9.250
# Epoch: 34, Loss: 8.285
# Epoch: 35, Loss: 8.045
# Epoch: 36, Loss: 7.533
# Epoch: 37, Loss: 7.193
# Epoch: 38, Loss: 7.626
# Epoch: 39, Loss: 8.672
# Epoch: 40, Loss: 7.310
# Epoch: 41, Loss: 6.141
# Epoch: 42, Loss: 7.733
# Epoch: 43, Loss: 8.302
# Epoch: 44, Loss: 6.345
# Epoch: 45, Loss: 7.930
# Epoch: 46, Loss: 6.625
# Epoch: 47, Loss: 8.034
# Epoch: 48, Loss: 7.577
# Epoch: 49, Loss: 7.880
# Epoch: 50, Loss: 6.734
# Epoch: 51, Loss: 6.798
# Epoch: 52, Loss: 6.163
# Epoch: 53, Loss: 6.941
# Epoch: 54, Loss: 7.750
# Epoch: 55, Loss: 8.487
# Epoch: 56, Loss: 7.025
# Epoch: 57, Loss: 7.466
# Epoch: 58, Loss: 7.884
# Epoch: 59, Loss: 6.980
# Epoch: 60, Loss: 5.411
# Epoch: 61, Loss: 7.812
# Epoch: 62, Loss: 6.462
# Epoch: 63, Loss: 6.674
# Epoch: 64, Loss: 7.099
# Epoch: 65, Loss: 5.998
# Epoch: 66, Loss: 6.810
# Epoch: 67, Loss: 5.647
# Epoch: 68, Loss: 5.990
# Epoch: 69, Loss: 6.309
# Epoch: 70, Loss: 6.477
# Epoch: 71, Loss: 6.244
# Epoch: 72, Loss: 7.799
# Epoch: 73, Loss: 6.161
# Epoch: 74, Loss: 6.957
# Epoch: 75, Loss: 6.573
# Epoch: 76, Loss: 5.674
# Epoch: 77, Loss: 5.988
# Epoch: 78, Loss: 6.177
# Epoch: 79, Loss: 5.634
# Epoch: 80, Loss: 5.413
# Epoch: 81, Loss: 7.604
# Epoch: 82, Loss: 6.197
# Epoch: 83, Loss: 5.859
# Epoch: 84, Loss: 6.188
# Epoch: 85, Loss: 6.541
# Epoch: 86, Loss: 6.914
# Epoch: 87, Loss: 5.780
# Epoch: 88, Loss: 6.320
# Epoch: 89, Loss: 5.559
# Epoch: 90, Loss: 5.771
# Epoch: 91, Loss: 5.893
# Epoch: 92, Loss: 7.034
# Epoch: 93, Loss: 6.161
# Epoch: 94, Loss: 5.809
# Epoch: 95, Loss: 6.139
# Epoch: 96, Loss: 5.197
# Epoch: 97, Loss: 5.018
# Epoch: 98, Loss: 4.839
# Epoch: 99, Loss: 4.449
# Epoch: 100, Loss: 4.884
# Epoch: 101, Loss: 4.917
# Epoch: 102, Loss: 6.282
# Epoch: 103, Loss: 5.994
# Epoch: 104, Loss: 5.782
# Epoch: 105, Loss: 6.111
# Epoch: 106, Loss: 5.915
# Epoch: 107, Loss: 5.145
# Epoch: 108, Loss: 5.524
# Epoch: 109, Loss: 5.134
# Epoch: 110, Loss: 5.974
# Epoch: 111, Loss: 4.006
# Epoch: 112, Loss: 4.738
# Epoch: 113, Loss: 5.897
# Epoch: 114, Loss: 5.445
# Epoch: 115, Loss: 4.778
# Epoch: 116, Loss: 4.724
# Epoch: 117, Loss: 3.968
# Epoch: 118, Loss: 5.429
# Epoch: 119, Loss: 5.779
# Epoch: 120, Loss: 4.822
# Epoch: 121, Loss: 5.276
# Epoch: 122, Loss: 4.535
# Epoch: 123, Loss: 5.008
# Epoch: 124, Loss: 4.817
# Epoch: 125, Loss: 4.709
# Epoch: 126, Loss: 5.106
# Epoch: 127, Loss: 5.298
# Epoch: 128, Loss: 4.767
# Epoch: 129, Loss: 5.065
# Epoch: 130, Loss: 4.297
# Epoch: 131, Loss: 5.163
# Epoch: 132, Loss: 5.510
# Epoch: 133, Loss: 5.103
# Epoch: 134, Loss: 5.174
# Epoch: 135, Loss: 4.673
# Epoch: 136, Loss: 4.324
# Epoch: 137, Loss: 4.999
# Epoch: 138, Loss: 5.013
# Epoch: 139, Loss: 5.265
# Epoch: 140, Loss: 5.241
# Epoch: 141, Loss: 5.148
# Epoch: 142, Loss: 5.284
# Epoch: 143, Loss: 4.678
# Epoch: 144, Loss: 4.723
# Epoch: 145, Loss: 4.696
# Epoch: 146, Loss: 5.234
# Epoch: 147, Loss: 5.013
# Epoch: 148, Loss: 5.194
# Epoch: 149, Loss: 4.708
# Epoch: 150, Loss: 4.916
# Epoch: 151, Loss: 6.287
# Epoch: 152, Loss: 4.629
# Epoch: 153, Loss: 4.091
# Epoch: 154, Loss: 4.656
# Epoch: 155, Loss: 4.838
# Epoch: 156, Loss: 5.318
# Epoch: 157, Loss: 4.705
# Epoch: 158, Loss: 4.784
# Epoch: 159, Loss: 3.714
# Epoch: 160, Loss: 4.625
# Epoch: 161, Loss: 5.380
# Epoch: 162, Loss: 4.239
# Epoch: 163, Loss: 4.230
# Epoch: 164, Loss: 4.510
# Epoch: 165, Loss: 4.396
# Epoch: 166, Loss: 4.647
# Epoch: 167, Loss: 4.684
# Epoch: 168, Loss: 4.538
# Epoch: 169, Loss: 4.666
# Epoch: 170, Loss: 3.661
# Epoch: 171, Loss: 4.313
# Epoch: 172, Loss: 4.601
# Epoch: 173, Loss: 4.826
# Epoch: 174, Loss: 4.297
# Epoch: 175, Loss: 4.052
# Epoch: 176, Loss: 3.669
# Epoch: 177, Loss: 4.231
# Epoch: 178, Loss: 4.715
# Epoch: 179, Loss: 3.925
# Epoch: 180, Loss: 4.399
# Epoch: 181, Loss: 4.638
# Epoch: 182, Loss: 3.993
# Epoch: 183, Loss: 4.901
# Epoch: 184, Loss: 4.801
# Epoch: 185, Loss: 4.372
# Epoch: 186, Loss: 4.900
# Epoch: 187, Loss: 4.942
# Epoch: 188, Loss: 4.463
# Epoch: 189, Loss: 4.580
# Epoch: 190, Loss: 4.051
# Epoch: 191, Loss: 3.899
# Epoch: 192, Loss: 4.919
# Epoch: 193, Loss: 4.626
# Epoch: 194, Loss: 4.516
# Epoch: 195, Loss: 4.411
# Epoch: 196, Loss: 4.727
# Epoch: 197, Loss: 4.214
# Epoch: 198, Loss: 4.219
# Epoch: 199, Loss: 4.410
# Epoch: 200, Loss: 4.197
# Epoch: 201, Loss: 4.990
# Epoch: 202, Loss: 4.118
# Epoch: 203, Loss: 3.875
# Epoch: 204, Loss: 3.827
# Epoch: 205, Loss: 4.489
# Epoch: 206, Loss: 4.665
# Epoch: 207, Loss: 4.569
# Epoch: 208, Loss: 4.831
# Epoch: 209, Loss: 4.095
# Epoch: 210, Loss: 4.016
# Epoch: 211, Loss: 4.676
# Epoch: 212, Loss: 4.056
# Epoch: 213, Loss: 4.211
# Epoch: 214, Loss: 4.570
# Epoch: 215, Loss: 4.451
# Epoch: 216, Loss: 4.555
# Epoch: 217, Loss: 4.672
# Epoch: 218, Loss: 4.079
# Epoch: 219, Loss: 4.024
# Epoch: 220, Loss: 4.142
# Epoch: 221, Loss: 4.237
# Epoch: 222, Loss: 4.561
# Epoch: 223, Loss: 4.328
# Epoch: 224, Loss: 4.376
# Epoch: 225, Loss: 4.003
# Epoch: 226, Loss: 4.278
# Epoch: 227, Loss: 4.098
# Epoch: 228, Loss: 3.868
# Epoch: 229, Loss: 4.461
# Epoch: 230, Loss: 4.193
# Epoch: 231, Loss: 3.555
# Epoch: 232, Loss: 3.939
# Epoch: 233, Loss: 3.772
# Epoch: 234, Loss: 3.975
# Epoch: 235, Loss: 4.392
# Epoch: 236, Loss: 4.503
# Epoch: 237, Loss: 4.059
# Epoch: 238, Loss: 3.698
# Epoch: 239, Loss: 3.761
# Epoch: 240, Loss: 4.475
# Epoch: 241, Loss: 4.792
# Epoch: 242, Loss: 4.269
# Epoch: 243, Loss: 4.095
# Epoch: 244, Loss: 3.884
# Epoch: 245, Loss: 4.252
# Epoch: 246, Loss: 4.042
# Epoch: 247, Loss: 4.249
# Epoch: 248, Loss: 3.866
# Epoch: 249, Loss: 4.413
# Epoch: 250, Loss: 4.172
# Epoch: 251, Loss: 3.909
# Epoch: 252, Loss: 4.110
# Epoch: 253, Loss: 4.380
# Epoch: 254, Loss: 3.702
# Epoch: 255, Loss: 4.654
# Epoch: 256, Loss: 4.166
# Epoch: 257, Loss: 4.394
# Epoch: 258, Loss: 4.323
# Epoch: 259, Loss: 3.932
# Epoch: 260, Loss: 4.254
# Epoch: 261, Loss: 3.916
# Epoch: 262, Loss: 4.093
# Epoch: 263, Loss: 3.862
# Epoch: 264, Loss: 3.899
# Epoch: 265, Loss: 4.210
# Epoch: 266, Loss: 4.827
# Epoch: 267, Loss: 3.930
# Epoch: 268, Loss: 4.448
# Epoch: 269, Loss: 4.323
# Epoch: 270, Loss: 3.891
# Epoch: 271, Loss: 3.652
# Epoch: 272, Loss: 3.862
# Epoch: 273, Loss: 4.198
# Epoch: 274, Loss: 3.849
# Epoch: 275, Loss: 4.388
# Epoch: 276, Loss: 4.435
# Epoch: 277, Loss: 4.251
# Epoch: 278, Loss: 3.919
# Epoch: 279, Loss: 3.976
# Epoch: 280, Loss: 3.858
# Epoch: 281, Loss: 4.080
# Epoch: 282, Loss: 4.225
# Epoch: 283, Loss: 3.806
# Epoch: 284, Loss: 3.767
# Epoch: 285, Loss: 4.125
# Epoch: 286, Loss: 3.817
# Epoch: 287, Loss: 3.585
# Epoch: 288, Loss: 4.326
# Epoch: 289, Loss: 3.683
# Epoch: 290, Loss: 4.229
# Epoch: 291, Loss: 4.007
# Epoch: 292, Loss: 3.716
# Epoch: 293, Loss: 4.026
# Epoch: 294, Loss: 4.156
# Epoch: 295, Loss: 4.119
# Epoch: 296, Loss: 3.764
# Epoch: 297, Loss: 4.275
# Epoch: 298, Loss: 3.506
# Epoch: 299, Loss: 3.821
# Epoch: 300, Loss: 4.031
# Epoch: 301, Loss: 4.493
# Epoch: 302, Loss: 3.798
# Epoch: 303, Loss: 3.933
# Epoch: 304, Loss: 4.233
# Epoch: 305, Loss: 3.860
# Epoch: 306, Loss: 4.236
# Epoch: 307, Loss: 3.017
# Epoch: 308, Loss: 3.776
# Epoch: 309, Loss: 4.079
# Epoch: 310, Loss: 4.068
# Epoch: 311, Loss: 3.795
# Epoch: 312, Loss: 4.256
# Epoch: 313, Loss: 4.082
# Epoch: 314, Loss: 3.780
# Epoch: 315, Loss: 3.972
# Epoch: 316, Loss: 3.890
# Epoch: 317, Loss: 4.037
# Epoch: 318, Loss: 3.645
# Epoch: 319, Loss: 4.106
# Epoch: 320, Loss: 4.155
# Epoch: 321, Loss: 3.902
# Epoch: 322, Loss: 3.742
# Epoch: 323, Loss: 3.526
# Epoch: 324, Loss: 3.982
# Epoch: 325, Loss: 4.025
# Epoch: 326, Loss: 4.647
# Epoch: 327, Loss: 4.036
# Epoch: 328, Loss: 3.604
# Epoch: 329, Loss: 3.211
# Epoch: 330, Loss: 3.871
# Epoch: 331, Loss: 3.696
# Epoch: 332, Loss: 3.511
# Epoch: 333, Loss: 3.455
# Epoch: 334, Loss: 4.030
# Epoch: 335, Loss: 3.154
# Epoch: 336, Loss: 3.882
# Epoch: 337, Loss: 3.763
# Epoch: 338, Loss: 4.071
# Epoch: 339, Loss: 3.878
# Epoch: 340, Loss: 4.234
# Epoch: 341, Loss: 3.791
# Epoch: 342, Loss: 3.660
# Epoch: 343, Loss: 4.190
# Epoch: 344, Loss: 4.502
# Epoch: 345, Loss: 3.553
# Epoch: 346, Loss: 3.392
# Epoch: 347, Loss: 3.895
# Epoch: 348, Loss: 3.780
# Epoch: 349, Loss: 3.359
# Epoch: 350, Loss: 4.021
# Epoch: 351, Loss: 3.334
# Epoch: 352, Loss: 3.842
# Epoch: 353, Loss: 3.957
# Epoch: 354, Loss: 3.584
# Epoch: 355, Loss: 3.996
# Epoch: 356, Loss: 3.789
# Epoch: 357, Loss: 3.761
# Epoch: 358, Loss: 4.409
# Epoch: 359, Loss: 3.923
# Epoch: 360, Loss: 3.797
# Epoch: 361, Loss: 3.953
# Epoch: 362, Loss: 3.645
# Epoch: 363, Loss: 3.824
# Epoch: 364, Loss: 3.902
# Epoch: 365, Loss: 3.977
# Epoch: 366, Loss: 3.875
# Epoch: 367, Loss: 3.398
# Epoch: 368, Loss: 3.221
# Epoch: 369, Loss: 3.756
# Epoch: 370, Loss: 3.453
# Epoch: 371, Loss: 3.890
# Epoch: 372, Loss: 3.200
# Epoch: 373, Loss: 3.354
# Epoch: 374, Loss: 3.592
# Epoch: 375, Loss: 3.612
# Epoch: 376, Loss: 4.062
# Epoch: 377, Loss: 3.338
# Epoch: 378, Loss: 3.661
# Epoch: 379, Loss: 3.687
# Epoch: 380, Loss: 3.745
# Epoch: 381, Loss: 3.220
# Epoch: 382, Loss: 3.505
# Epoch: 383, Loss: 3.528
# Epoch: 384, Loss: 3.209
# Epoch: 385, Loss: 3.319
# Epoch: 386, Loss: 3.972
# Epoch: 387, Loss: 3.373
# Epoch: 388, Loss: 3.659
# Epoch: 389, Loss: 3.377
# Epoch: 390, Loss: 3.901
# Epoch: 391, Loss: 3.568
# Epoch: 392, Loss: 3.916
# Epoch: 393, Loss: 3.516
# Epoch: 394, Loss: 3.706
# Epoch: 395, Loss: 3.752
# Epoch: 396, Loss: 3.944
# Epoch: 397, Loss: 3.823
# Epoch: 398, Loss: 4.411
# Epoch: 399, Loss: 3.685
# Epoch: 400, Loss: 4.002
# Epoch: 401, Loss: 3.775
# Epoch: 402, Loss: 3.898
# Epoch: 403, Loss: 3.838
# Epoch: 404, Loss: 3.700
# Epoch: 405, Loss: 3.194
# Epoch: 406, Loss: 3.555
# Epoch: 407, Loss: 3.517
# Epoch: 408, Loss: 3.954
# Epoch: 409, Loss: 3.676
# Epoch: 410, Loss: 3.656
# Epoch: 411, Loss: 3.775
# Epoch: 412, Loss: 4.231
# Epoch: 413, Loss: 3.884
# Epoch: 414, Loss: 3.713
# Epoch: 415, Loss: 3.391
# Epoch: 416, Loss: 3.578
# Epoch: 417, Loss: 3.465
# Epoch: 418, Loss: 3.770
# Epoch: 419, Loss: 3.790
# Epoch: 420, Loss: 3.992
# Epoch: 421, Loss: 3.682
# Epoch: 422, Loss: 3.442
# Epoch: 423, Loss: 3.348
# Epoch: 424, Loss: 3.371
# Epoch: 425, Loss: 3.777
# Epoch: 426, Loss: 3.009
# Epoch: 427, Loss: 3.698
# Epoch: 428, Loss: 3.906
# Epoch: 429, Loss: 3.666
# Epoch: 430, Loss: 3.716
# Epoch: 431, Loss: 3.761
# Epoch: 432, Loss: 3.647
# Epoch: 433, Loss: 3.297
# Epoch: 434, Loss: 3.354
# Epoch: 435, Loss: 4.022
# Epoch: 436, Loss: 3.481
# Epoch: 437, Loss: 4.036
# Epoch: 438, Loss: 3.228
# Epoch: 439, Loss: 3.777
# Epoch: 440, Loss: 3.715
# Epoch: 441, Loss: 3.759
# Epoch: 442, Loss: 3.176
# Epoch: 443, Loss: 3.790
# Epoch: 444, Loss: 3.865
# Epoch: 445, Loss: 3.368
# Epoch: 446, Loss: 3.674
# Epoch: 447, Loss: 3.314
# Epoch: 448, Loss: 3.675
# Epoch: 449, Loss: 3.652
# Epoch: 450, Loss: 3.629
# Epoch: 451, Loss: 3.145
# Epoch: 452, Loss: 3.476
# Epoch: 453, Loss: 3.730
# Epoch: 454, Loss: 3.356
# Epoch: 455, Loss: 3.853
# Epoch: 456, Loss: 3.878
# Epoch: 457, Loss: 3.557
# Epoch: 458, Loss: 3.578
# Epoch: 459, Loss: 3.765
# Epoch: 460, Loss: 4.071
# Epoch: 461, Loss: 3.501
# Epoch: 462, Loss: 3.458
# Epoch: 463, Loss: 3.851
# Epoch: 464, Loss: 3.561
# Epoch: 465, Loss: 2.949
# Epoch: 466, Loss: 3.930
# Epoch: 467, Loss: 3.237
# Epoch: 468, Loss: 3.741
# Epoch: 469, Loss: 3.707
# Epoch: 470, Loss: 3.528
# Epoch: 471, Loss: 3.607
# Epoch: 472, Loss: 3.600
# Epoch: 473, Loss: 3.534
# Epoch: 474, Loss: 3.594
# Epoch: 475, Loss: 3.228
# Epoch: 476, Loss: 3.876
# Epoch: 477, Loss: 3.324
# Epoch: 478, Loss: 3.551
# Epoch: 479, Loss: 3.474
# Epoch: 480, Loss: 3.299
# Epoch: 481, Loss: 3.374
# Epoch: 482, Loss: 4.043
# Epoch: 483, Loss: 3.823
# Epoch: 484, Loss: 3.242
# Epoch: 485, Loss: 3.321
# Epoch: 486, Loss: 3.685
# Epoch: 487, Loss: 3.776
# Epoch: 488, Loss: 3.282
# Epoch: 489, Loss: 2.877
# Epoch: 490, Loss: 3.750
# Epoch: 491, Loss: 3.496
# Epoch: 492, Loss: 3.639
# Epoch: 493, Loss: 3.416
# Epoch: 494, Loss: 3.251
# Epoch: 495, Loss: 4.013
# Epoch: 496, Loss: 3.647
# Epoch: 497, Loss: 3.501
# Epoch: 498, Loss: 4.009
# Epoch: 499, Loss: 4.102
# Epoch: 500, Loss: 3.312
# Epoch: 501, Loss: 3.369
# Epoch: 502, Loss: 3.636
# Epoch: 503, Loss: 3.754
# Epoch: 504, Loss: 3.262
# Epoch: 505, Loss: 3.345
# Epoch: 506, Loss: 3.696
# Epoch: 507, Loss: 3.271
# Epoch: 508, Loss: 3.785
# Epoch: 509, Loss: 4.040
# Epoch: 510, Loss: 3.420
# Epoch: 511, Loss: 3.341
# Epoch: 512, Loss: 3.334
# Epoch: 513, Loss: 3.179
# Epoch: 514, Loss: 3.340
# Epoch: 515, Loss: 3.018
# Epoch: 516, Loss: 3.501
# Epoch: 517, Loss: 3.869
# Epoch: 518, Loss: 3.369
# Epoch: 519, Loss: 3.368
# Epoch: 520, Loss: 3.365
# Epoch: 521, Loss: 3.565
# Epoch: 522, Loss: 3.481
# Epoch: 523, Loss: 3.332
# Epoch: 524, Loss: 3.358
# Epoch: 525, Loss: 3.554
# Epoch: 526, Loss: 3.124
# Epoch: 527, Loss: 3.776
# Epoch: 528, Loss: 3.931
# Epoch: 529, Loss: 3.465
# Epoch: 530, Loss: 3.777
# Epoch: 531, Loss: 3.458
# Epoch: 532, Loss: 3.282
# Epoch: 533, Loss: 3.235
# Epoch: 534, Loss: 3.228
# Epoch: 535, Loss: 3.345
# Epoch: 536, Loss: 3.526
# Epoch: 537, Loss: 3.775
# Epoch: 538, Loss: 3.228
# Epoch: 539, Loss: 3.295
# Epoch: 540, Loss: 3.754
# Epoch: 541, Loss: 3.497
# Epoch: 542, Loss: 3.783
# Epoch: 543, Loss: 3.709
# Epoch: 544, Loss: 3.046
# Epoch: 545, Loss: 2.994
# Epoch: 546, Loss: 3.181
# Epoch: 547, Loss: 3.374
# Epoch: 548, Loss: 3.544
# Epoch: 549, Loss: 3.452
# Epoch: 550, Loss: 3.258
# Epoch: 551, Loss: 3.751
# Epoch: 552, Loss: 3.181
# Epoch: 553, Loss: 3.624
# Epoch: 554, Loss: 3.683
# Epoch: 555, Loss: 3.140
# Epoch: 556, Loss: 3.647
# Epoch: 557, Loss: 3.238
# Epoch: 558, Loss: 3.190
# Epoch: 559, Loss: 3.316
# Epoch: 560, Loss: 3.521
# Epoch: 561, Loss: 3.654
# Epoch: 562, Loss: 2.997
# Epoch: 563, Loss: 3.779
# Epoch: 564, Loss: 3.918
# Epoch: 565, Loss: 3.821
# Epoch: 566, Loss: 3.661
# Epoch: 567, Loss: 3.616
# Epoch: 568, Loss: 3.498
# Epoch: 569, Loss: 3.243
# Epoch: 570, Loss: 3.289
# Epoch: 571, Loss: 3.383
# Epoch: 572, Loss: 3.468
# Epoch: 573, Loss: 3.186
# Epoch: 574, Loss: 3.694
# Epoch: 575, Loss: 3.271
# Epoch: 576, Loss: 3.195
# Epoch: 577, Loss: 3.033
# Epoch: 578, Loss: 3.253
# Epoch: 579, Loss: 3.092
# Epoch: 580, Loss: 3.687
# Epoch: 581, Loss: 3.160
# Epoch: 582, Loss: 3.786
# Epoch: 583, Loss: 3.224
# Epoch: 584, Loss: 3.256
# Epoch: 585, Loss: 3.446
# Epoch: 586, Loss: 3.311
# Epoch: 587, Loss: 3.934
# Epoch: 588, Loss: 3.646
# Epoch: 589, Loss: 3.659
# Epoch: 590, Loss: 3.410
# Epoch: 591, Loss: 3.328
# Epoch: 592, Loss: 3.423
# Epoch: 593, Loss: 3.753
# Epoch: 594, Loss: 3.625
# Epoch: 595, Loss: 3.390
# Epoch: 596, Loss: 3.811
# Epoch: 597, Loss: 3.723
# Epoch: 598, Loss: 3.137
# Epoch: 599, Loss: 3.525
# Epoch: 600, Loss: 3.225
# Epoch: 601, Loss: 3.659
# Epoch: 602, Loss: 3.636
# Epoch: 603, Loss: 3.425
# Epoch: 604, Loss: 3.537
# Epoch: 605, Loss: 3.747
# Epoch: 606, Loss: 3.226
# Epoch: 607, Loss: 3.745
# Epoch: 608, Loss: 3.580
# Epoch: 609, Loss: 4.019
# Epoch: 610, Loss: 3.617
# Epoch: 611, Loss: 3.661
# Epoch: 612, Loss: 3.371
# Epoch: 613, Loss: 3.471
# Epoch: 614, Loss: 3.216
# Epoch: 615, Loss: 3.089
# Epoch: 616, Loss: 3.323
# Epoch: 617, Loss: 3.099
# Epoch: 618, Loss: 3.418
# Epoch: 619, Loss: 3.398
# Epoch: 620, Loss: 3.239
# Epoch: 621, Loss: 3.286
# Epoch: 622, Loss: 3.438
# Epoch: 623, Loss: 3.448
# Epoch: 624, Loss: 3.355
# Epoch: 625, Loss: 3.185
# Epoch: 626, Loss: 3.620
# Epoch: 627, Loss: 3.585
# Epoch: 628, Loss: 3.263
# Epoch: 629, Loss: 4.105
# Epoch: 630, Loss: 3.547
# Epoch: 631, Loss: 3.257
# Epoch: 632, Loss: 3.205
# Epoch: 633, Loss: 3.843
# Epoch: 634, Loss: 3.582
# Epoch: 635, Loss: 2.870
# Epoch: 636, Loss: 3.146
# Epoch: 637, Loss: 3.777
# Epoch: 638, Loss: 3.263
# Epoch: 639, Loss: 3.562
# Epoch: 640, Loss: 3.272
# Epoch: 641, Loss: 3.235
# Epoch: 642, Loss: 3.887
# Epoch: 643, Loss: 3.862
# Epoch: 644, Loss: 3.713
# Epoch: 645, Loss: 3.547
# Epoch: 646, Loss: 3.411
# Epoch: 647, Loss: 3.051
# Epoch: 648, Loss: 3.208
# Epoch: 649, Loss: 3.074
# Epoch: 650, Loss: 3.422
# Epoch: 651, Loss: 3.219
# Epoch: 652, Loss: 3.670
# Epoch: 653, Loss: 3.336
# Epoch: 654, Loss: 3.359
# Epoch: 655, Loss: 2.984
# Epoch: 656, Loss: 3.271
# Epoch: 657, Loss: 3.054
# Epoch: 658, Loss: 3.356
# Epoch: 659, Loss: 3.407
# Epoch: 660, Loss: 2.916
# Epoch: 661, Loss: 3.362
# Epoch: 662, Loss: 3.413
# Epoch: 663, Loss: 3.049
# Epoch: 664, Loss: 4.043
# Epoch: 665, Loss: 3.150
# Epoch: 666, Loss: 3.163
# Epoch: 667, Loss: 3.444
# Epoch: 668, Loss: 3.142
# Epoch: 669, Loss: 3.240
# Epoch: 670, Loss: 3.540
# Epoch: 671, Loss: 3.176
# Epoch: 672, Loss: 3.369
# Epoch: 673, Loss: 3.111
# Epoch: 674, Loss: 3.505
# Epoch: 675, Loss: 3.658
# Epoch: 676, Loss: 3.500
# Epoch: 677, Loss: 3.034
# Epoch: 678, Loss: 3.571
# Epoch: 679, Loss: 3.916
# Epoch: 680, Loss: 3.128
# Epoch: 681, Loss: 3.144
# Epoch: 682, Loss: 3.218
# Epoch: 683, Loss: 3.447
# Epoch: 684, Loss: 3.324
# Epoch: 685, Loss: 3.360
# Epoch: 686, Loss: 3.272
# Epoch: 687, Loss: 3.564
# Epoch: 688, Loss: 3.262
# Epoch: 689, Loss: 3.467
# Epoch: 690, Loss: 2.977
# Epoch: 691, Loss: 3.519
# Epoch: 692, Loss: 3.545
# Epoch: 693, Loss: 3.316
# Epoch: 694, Loss: 3.297
# Epoch: 695, Loss: 3.357
# Epoch: 696, Loss: 3.411
# Epoch: 697, Loss: 3.476
# Epoch: 698, Loss: 3.120
# Epoch: 699, Loss: 2.912
# Epoch: 700, Loss: 3.215
# Epoch: 701, Loss: 3.475
# Epoch: 702, Loss: 2.817
# Epoch: 703, Loss: 3.539
# Epoch: 704, Loss: 3.165
# Epoch: 705, Loss: 3.238
# Epoch: 706, Loss: 3.579
# Epoch: 707, Loss: 2.977
# Epoch: 708, Loss: 3.203
# Epoch: 709, Loss: 3.669
# Epoch: 710, Loss: 3.601
# Epoch: 711, Loss: 3.040
# Epoch: 712, Loss: 3.141
# Epoch: 713, Loss: 3.643
# Epoch: 714, Loss: 3.531
# Epoch: 715, Loss: 3.446
# Epoch: 716, Loss: 3.345
# Epoch: 717, Loss: 3.481
# Epoch: 718, Loss: 2.950
# Epoch: 719, Loss: 3.350
# Epoch: 720, Loss: 3.049
# Epoch: 721, Loss: 3.231
# Epoch: 722, Loss: 2.980
# Epoch: 723, Loss: 3.091
# Epoch: 724, Loss: 3.301
# Epoch: 725, Loss: 3.287
# Epoch: 726, Loss: 3.236
# Epoch: 727, Loss: 3.382
# Epoch: 728, Loss: 3.466
# Epoch: 729, Loss: 3.180
# Epoch: 730, Loss: 3.494
# Epoch: 731, Loss: 3.332
# Epoch: 732, Loss: 3.661
# Epoch: 733, Loss: 3.451
# Epoch: 734, Loss: 3.186
# Epoch: 735, Loss: 3.607
# Epoch: 736, Loss: 3.330
# Epoch: 737, Loss: 3.299
# Epoch: 738, Loss: 3.240
# Epoch: 739, Loss: 3.132
# Epoch: 740, Loss: 3.500
# Epoch: 741, Loss: 2.971
# Epoch: 742, Loss: 3.423
# Epoch: 743, Loss: 3.173
# Epoch: 744, Loss: 3.100
# Epoch: 745, Loss: 3.403
# Epoch: 746, Loss: 3.696
# Epoch: 747, Loss: 3.313
# Epoch: 748, Loss: 2.886
# Epoch: 749, Loss: 3.322
# Epoch: 750, Loss: 3.249
# Epoch: 751, Loss: 3.295
# Epoch: 752, Loss: 3.297
# Epoch: 753, Loss: 3.432
# Epoch: 754, Loss: 2.736
# Epoch: 755, Loss: 3.391
# Epoch: 756, Loss: 3.340
# Epoch: 757, Loss: 3.269
# Epoch: 758, Loss: 3.728
# Epoch: 759, Loss: 3.710
# Epoch: 760, Loss: 3.388
# Epoch: 761, Loss: 3.087
# Epoch: 762, Loss: 3.589
# Epoch: 763, Loss: 3.225
# Epoch: 764, Loss: 3.649
# Epoch: 765, Loss: 3.680
# Epoch: 766, Loss: 3.576
# Epoch: 767, Loss: 3.808
# Epoch: 768, Loss: 3.365
# Epoch: 769, Loss: 3.451
# Epoch: 770, Loss: 3.213
# Epoch: 771, Loss: 3.258
# Epoch: 772, Loss: 3.594
# Epoch: 773, Loss: 3.276
# Epoch: 774, Loss: 3.054
# Epoch: 775, Loss: 3.343
# Epoch: 776, Loss: 3.606
# Epoch: 777, Loss: 3.141
# Epoch: 778, Loss: 3.453
# Epoch: 779, Loss: 3.315
# Epoch: 780, Loss: 3.028
# Epoch: 781, Loss: 3.309
# Epoch: 782, Loss: 3.643
# Epoch: 783, Loss: 3.191
# Epoch: 784, Loss: 3.679
# Epoch: 785, Loss: 3.460
# Epoch: 786, Loss: 3.061
# Epoch: 787, Loss: 3.601
# Epoch: 788, Loss: 3.103
# Epoch: 789, Loss: 3.153
# Epoch: 790, Loss: 3.066
# Epoch: 791, Loss: 3.212
# Epoch: 792, Loss: 3.412
# Epoch: 793, Loss: 3.665
# Epoch: 794, Loss: 3.275
# Epoch: 795, Loss: 3.226
# Epoch: 796, Loss: 2.777
# Epoch: 797, Loss: 3.520
# Epoch: 798, Loss: 3.503
# Epoch: 799, Loss: 3.331
# Epoch: 800, Loss: 3.350
# Epoch: 801, Loss: 3.416
# Epoch: 802, Loss: 2.934
# Epoch: 803, Loss: 3.252
# Epoch: 804, Loss: 3.704
# Epoch: 805, Loss: 3.669
# Epoch: 806, Loss: 3.419
# Epoch: 807, Loss: 3.146
# Epoch: 808, Loss: 3.088
# Epoch: 809, Loss: 3.241
# Epoch: 810, Loss: 3.290
# Epoch: 811, Loss: 3.034
# Epoch: 812, Loss: 3.493
# Epoch: 813, Loss: 3.357
# Epoch: 814, Loss: 2.809
# Epoch: 815, Loss: 3.132
# Epoch: 816, Loss: 3.062
# Epoch: 817, Loss: 3.246
# Epoch: 818, Loss: 3.334
# Epoch: 819, Loss: 3.276
# Epoch: 820, Loss: 3.834
# Epoch: 821, Loss: 3.437
# Epoch: 822, Loss: 3.170
# Epoch: 823, Loss: 3.046
# Epoch: 824, Loss: 2.646
# Epoch: 825, Loss: 3.161
# Epoch: 826, Loss: 3.043
# Epoch: 827, Loss: 3.437
# Epoch: 828, Loss: 3.332
# Epoch: 829, Loss: 3.101
# Epoch: 830, Loss: 3.226
# Epoch: 831, Loss: 3.535
# Epoch: 832, Loss: 3.083
# Epoch: 833, Loss: 3.551
# Epoch: 834, Loss: 3.363
# Epoch: 835, Loss: 3.100
# Epoch: 836, Loss: 2.851
# Epoch: 837, Loss: 3.454
# Epoch: 838, Loss: 3.122
# Epoch: 839, Loss: 3.200
# Epoch: 840, Loss: 3.488
# Epoch: 841, Loss: 3.388
# Epoch: 842, Loss: 3.432
# Epoch: 843, Loss: 2.930
# Epoch: 844, Loss: 3.280
# Epoch: 845, Loss: 3.251
# Epoch: 846, Loss: 3.152
# Epoch: 847, Loss: 3.557
# Epoch: 848, Loss: 3.511
# Epoch: 849, Loss: 4.097
# Epoch: 850, Loss: 3.493
# Epoch: 851, Loss: 3.487
# Epoch: 852, Loss: 3.468
# Epoch: 853, Loss: 3.614
# Epoch: 854, Loss: 2.856
# Epoch: 855, Loss: 3.536
# Epoch: 856, Loss: 3.339
# Epoch: 857, Loss: 3.322
# Epoch: 858, Loss: 3.385
# Epoch: 859, Loss: 3.494
# Epoch: 860, Loss: 3.439
# Epoch: 861, Loss: 3.151
# Epoch: 862, Loss: 3.485
# Epoch: 863, Loss: 3.646
# Epoch: 864, Loss: 3.117
# Epoch: 865, Loss: 2.955
# Epoch: 866, Loss: 3.185
# Epoch: 867, Loss: 3.520
# Epoch: 868, Loss: 3.494
# Epoch: 869, Loss: 3.576
# Epoch: 870, Loss: 2.877
# Epoch: 871, Loss: 3.245
# Epoch: 872, Loss: 2.933
# Epoch: 873, Loss: 2.779
# Epoch: 874, Loss: 3.571
# Epoch: 875, Loss: 3.387
# Epoch: 876, Loss: 3.297
# Epoch: 877, Loss: 3.659
# Epoch: 878, Loss: 2.928
# Epoch: 879, Loss: 3.499
# Epoch: 880, Loss: 3.224
# Epoch: 881, Loss: 3.037
# Epoch: 882, Loss: 3.357
# Epoch: 883, Loss: 3.507
# Epoch: 884, Loss: 3.340
# Epoch: 885, Loss: 3.371
# Epoch: 886, Loss: 3.286
# Epoch: 887, Loss: 3.115
# Epoch: 888, Loss: 3.401
# Epoch: 889, Loss: 3.284
# Epoch: 890, Loss: 3.485
# Epoch: 891, Loss: 3.360
# Epoch: 892, Loss: 3.366
# Epoch: 893, Loss: 3.250
# Epoch: 894, Loss: 3.446
# Epoch: 895, Loss: 3.604
# Epoch: 896, Loss: 3.102
# Epoch: 897, Loss: 3.023
# Epoch: 898, Loss: 3.765
# Epoch: 899, Loss: 3.041
# Epoch: 900, Loss: 3.481
# Epoch: 901, Loss: 2.947
# Epoch: 902, Loss: 3.575
# Epoch: 903, Loss: 3.514
# Epoch: 904, Loss: 3.241
# Epoch: 905, Loss: 3.595
# Epoch: 906, Loss: 3.713
# Epoch: 907, Loss: 3.321
# Epoch: 908, Loss: 3.085
# Epoch: 909, Loss: 3.146
# Epoch: 910, Loss: 3.022
# Epoch: 911, Loss: 3.385
# Epoch: 912, Loss: 3.074
# Epoch: 913, Loss: 3.730
# Epoch: 914, Loss: 3.516
# Epoch: 915, Loss: 3.151
# Epoch: 916, Loss: 3.106
# Epoch: 917, Loss: 3.631
# Epoch: 918, Loss: 3.436
# Epoch: 919, Loss: 3.035
# Epoch: 920, Loss: 3.641
# Epoch: 921, Loss: 3.383
# Epoch: 922, Loss: 3.251
# Epoch: 923, Loss: 3.140
# Epoch: 924, Loss: 3.197
# Epoch: 925, Loss: 2.948
# Epoch: 926, Loss: 2.921
# Epoch: 927, Loss: 2.860
# Epoch: 928, Loss: 2.941
# Epoch: 929, Loss: 3.008
# Epoch: 930, Loss: 2.975
# Epoch: 931, Loss: 3.747
# Epoch: 932, Loss: 3.130
# Epoch: 933, Loss: 3.505
# Epoch: 934, Loss: 2.941
# Epoch: 935, Loss: 2.795
# Epoch: 936, Loss: 3.262
# Epoch: 937, Loss: 2.856
# Epoch: 938, Loss: 3.706
# Epoch: 939, Loss: 3.524
# Epoch: 940, Loss: 3.269
# Epoch: 941, Loss: 3.337
# Epoch: 942, Loss: 3.188
# Epoch: 943, Loss: 3.152
# Epoch: 944, Loss: 3.486
# Epoch: 945, Loss: 3.131
# Epoch: 946, Loss: 3.003
# Epoch: 947, Loss: 3.572
# Epoch: 948, Loss: 3.115
# Epoch: 949, Loss: 3.320
# Epoch: 950, Loss: 3.678
# Epoch: 951, Loss: 3.595
# Epoch: 952, Loss: 3.222
# Epoch: 953, Loss: 3.218
# Epoch: 954, Loss: 3.228
# Epoch: 955, Loss: 3.180
# Epoch: 956, Loss: 3.762
# Epoch: 957, Loss: 3.199
# Epoch: 958, Loss: 3.322
# Epoch: 959, Loss: 3.386
# Epoch: 960, Loss: 3.358
# Epoch: 961, Loss: 3.105
# Epoch: 962, Loss: 3.209
# Epoch: 963, Loss: 2.956
# Epoch: 964, Loss: 3.191
# Epoch: 965, Loss: 3.320
# Epoch: 966, Loss: 3.079
# Epoch: 967, Loss: 2.893
# Epoch: 968, Loss: 3.018
# Epoch: 969, Loss: 2.796
# Epoch: 970, Loss: 3.276
# Epoch: 971, Loss: 2.963
# Epoch: 972, Loss: 2.829
# Epoch: 973, Loss: 3.007
# Epoch: 974, Loss: 2.836
# Epoch: 975, Loss: 3.272
# Epoch: 976, Loss: 3.410
# Epoch: 977, Loss: 3.493
# Epoch: 978, Loss: 3.316
# Epoch: 979, Loss: 2.944
# Epoch: 980, Loss: 3.362
# Epoch: 981, Loss: 3.236
# Epoch: 982, Loss: 3.093
# Epoch: 983, Loss: 3.713
# Epoch: 984, Loss: 3.547
# Epoch: 985, Loss: 3.113
# Epoch: 986, Loss: 3.541
# Epoch: 987, Loss: 3.104
# Epoch: 988, Loss: 2.961
# Epoch: 989, Loss: 3.467
# Epoch: 990, Loss: 3.194
# Epoch: 991, Loss: 3.362
# Epoch: 992, Loss: 3.140
# Epoch: 993, Loss: 3.221
# Epoch: 994, Loss: 3.342
# Epoch: 995, Loss: 3.166
# Epoch: 996, Loss: 3.375
# Epoch: 997, Loss: 3.111
# Epoch: 998, Loss: 3.556
# Epoch: 999, Loss: 2.962
# Epoch: 1000, Loss: 3.526

# %%
X_.shape
# Out:
# (506, 13)

# %%
y_.shape
# Out:
# (506,)

# %%
W1_.shape
# Out:
# (13, 10)

# %%
W2_.shape
# Out:
# (10, 1)

# %%
b2_.shape
# Out:
# (1,)
